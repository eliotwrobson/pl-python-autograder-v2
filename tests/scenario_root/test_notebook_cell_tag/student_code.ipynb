# %% [markdown]
# # Homework
# Put your solutions in cells tagged `#grade`.

# %%
# Scratch work — NOT tagged, must be excluded by the grader
raise ValueError('This untagged cell must not run during grading')

# %%
#grade
# Tagged cell: defines the graded answer
x = 99

def multiply(a, b):
    return a * b
