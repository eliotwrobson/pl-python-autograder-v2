# %% [markdown]
# # My Python Homework
# Student solution notebook.

# %%
# A simple variable
x = 42

# %%
def add(a, b):
    return a + b

# %%
# Some scratch work the student left in (should still be included)
result = add(1, 2)
print(result)
